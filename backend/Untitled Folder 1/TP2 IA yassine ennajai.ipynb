# %%
# !pip install transformers datasets huggingface_hub

# %%
from huggingface_hub import login

# Cette fonction ouvrira un widget interactif dans Colab
login()

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("gpt2")
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
# Exemple d'utilisation
input_text = "The future of AI is"
inputs = tokenizer(input_text, return_tensors="pt")
outputs = model.generate(**inputs, max_length=50)
print(tokenizer.decode(outputs[0]))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future of AI is uncertain. The future of AI is uncertain.
#
# The future

# %%
from datasets import load_dataset

ds = load_dataset("imdb", split="train[:500]")
ds[:3]
# Out:
# README.md: 0.00B [00:00, ?B/s]
# plain_text/train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# plain_text/test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# plain_text/unsupervised-00000-of-00001.p(…):   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# ...

# %%
import requests

# NOUVELLE URL - utilisez router.huggingface.co
API_URL = "https://router.huggingface.co/hf-inference/models/bigscience/bloom"
headers = {"Authorization": "Bearer hf_YYr8pFRUQfLfby7cyghkjJKYIvDpoMBEIr"}
payload = {
    "inputs": "Bonjour, l'intelligence artificielle est",
    "parameters": {
        "max_new_tokens": 50,
        "temperature": 0.7
    }
}
try:
    print(" Appel de l'API Hugging Face...")
    resp = requests.post(API_URL, headers=headers, json=payload)

    if resp.status_code == 200:
        result = resp.json()
        print("Réponse reçue :")
        print(result[0]['generated_text'])
    else:
        print(f"Erreur {resp.status_code}: {resp.text}")

except Exception as e:
    print(f"Erreur lors de l'appel API: {e}")
# Out:
#  Appel de l'API Hugging Face...
# Erreur 401: {"error":"Invalid username or password."}
