# %%
# !pip install huggingface_hub --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.0/516.0 kB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.57.1 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 1.1.5 which is incompatible.
# ...

# %%
from huggingface_hub import login

login()

# %%
from huggingface_hub import HfApi

# ضع هنا token ديالك
api = HfApi(token="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")  # عوض hf_XXXXX بالتوكن ديالك

# تأكد الاتصال
user = api.whoami()
print(user)
# Out:
# {'type': 'user', 'id': '691f52b42b108eebc6bfd56e', 'name': 'WSwalid', 'fullname': 'sabri', 'isPro': False, 'avatarUrl': '/avatars/229ad450138b9692967ee26e058d521c.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'notebooks', 'role': 'fineGrained', 'createdAt': '2025-11-23T16:36:46.263Z', 'fineGrained': {'canReadGatedRepos': True, 'global': [], 'scoped': [{'entity': {'_id': '691f52b42b108eebc6bfd56e', 'type': 'user', 'name': 'WSwalid'}, 'permissions': ['repo.content.read']}]}}}}

# %%
from huggingface_hub import list_models

# البحث عن 5 نماذج لتوليد النصوص
models = list_models(filter="text-generation", limit=5)
for m in models:
    print(m.modelId)
# Out:
# WeiboAI/VibeThinker-1.5B
# moonshotai/Kimi-K2-Thinking
# maya-research/maya1
# miromind-ai/MiroThinker-v1.0-72B
# salakash/SamKash-Tolstoy

# %%
# !pip install --upgrade transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 8.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.1.5
#     Uninstalling huggingface_hub-1.1.5:
#       Successfully uninstalled huggingface_hub-1.1.5
# ...

# %%
# !pip install torch --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "WeiboAI/VibeThinker-1.5B"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# ...

# %%
input_text = "مرحبا، الذكاء الاصطناعي هو"
inputs = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**inputs, max_length=80)
text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# مرحبا، الذكاء الاصطناعي هوطناعينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينينين

# %%
import requests

API_URL = "https://router.huggingface.co/hf-inference/models/bigscience/bloom-560m"

headers = {
    "Authorization": "Bearer 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"
}

payload = {
    "inputs": "Bonjour, l'intelligence artificielle est",
    "parameters": {
        "max_new_tokens": 50,
        "temperature": 0.7
    }
}

resp = requests.post(API_URL, headers=headers, json=payload)

try:
    print(resp.json())
except Exception:
    print(resp.text)
# Out:
# Not Found
